# %%
import notar.image_load_and_converttion.load as load
# Out:
# /home/mikkel/miniconda3/envs/Image/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dirr="data/data1/dicom/BackROI.png"
# BackROI.png, LiverROI.png, KidneyROI.png and the
# AortaROI.png)
i1=load.load_im(dirr)

dirr="data/data1/dicom/LiverROI.png"
# BackROI.png, LiverROI.png, KidneyROI.png and the
# AortaROI.png)
i2=load.load_im(dirr)

dirr="data/data1/dicom/KidneyROI.png"
# BackROI.png, LiverROI.png, KidneyROI.png and the
# AortaROI.png)
i3=load.load_im(dirr)

dirr="data/data1/dicom/AortaROI.png"
# BackROI.png, LiverROI.png, KidneyROI.png and the
# AortaROI.png)
i4=load.load_im(dirr)

dirr="data/data1/dicom/AortaROI.png"
# BackROI.png, LiverROI.png, KidneyROI.png and the
# AortaROI.png)
i4=load.load_im(dirr)
# Out:
# Shape of image is (512, 512)
#  data uint8
# Shape of image is (512, 512)
#  data uint8
# Shape of image is (512, 512)
#  data uint8
# /home/mikkel/miniconda3/envs/Image/lib/python3.9/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# Shape of image is (512, 512)
#  data uint8
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/mikkel/git/biledanalyse_ex/exmanen1.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:/home/mikkel/git/biledanalyse_ex/exmanen1.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a> dirr="data/data1/dicom.dcm"
#      <a href='vscode-notebook-cell:/home/mikkel/git/biledanalyse_ex/exmanen1.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a> # BackROI.png, LiverROI.png, KidneyROI.png and the
# ...
